# %% [markdown]
# # 1. Identifying Data Types
#
# ## Concept
#
# Data types tell us what kind of values are stored in each column. Correctly identifying data types is an important part of data preprocessing because different types of data require different preprocessing techniques.
#
# Common data types include:
#
# - Numerical data
# - Categorical data
# - Boolean data
# - Date/Time data
# - String data
#
# ## Example
#
# In our telecom customer churn dataset:
#
# - `monthly_charges` is numerical.
# - `gender` is categorical/string data.
# - `senior_citizen` is a binary flag stored as an integer.
# - `customer_id` is an identifier stored as a string.
# - `churn` is the target variable stored as a string.
#
# ## Implementation
#
# We first inspect the data types of all columns using Pandas.
#
# ## Output
#
# The output shows the current data type of every column.
#
# ## Interpretation
#
# The data types help us understand which columns may require conversion before Machine Learning.
#
# ## Insight
#
# The dataset contains a mixture of numerical and categorical information, so a single preprocessing technique cannot be applied to every column.
#
# ## AI/ML Relevance
#
# Correct data types help us apply appropriate preprocessing techniques such as encoding categorical variables and scaling numerical variables.

# %%
import pandas as pd

df = pd.read_csv("Titanic-Dataset.csv")

print("Data Types:")
print(df.dtypes)
# Out:
# Data Types:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name               str
# Sex                str
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket             str
# Fare           float64
# Cabin              str
# Embarked           str
# dtype: object

# %% [markdown]
# # 2. Numerical Data
#
# ## Concept
#
# Numerical data contains values that represent numbers and can be used for mathematical calculations.
#
# ## Example
#
# In the Titanic dataset, `Age`, `Fare`, `SibSp`, and `Parch` are numerical columns.
#
# ## Implementation
#
# We can identify numerical columns using Pandas.
#
# ## Output
#
# The numerical columns are displayed.
#
# ## Interpretation
#
# These columns can be used for statistical analysis and numerical Machine Learning operations.
#
# ## Insight
#
# Identifying numerical features helps us decide where techniques such as scaling, transformation, and outlier treatment may be required.
#
# ## AI/ML Relevance
#
# Most Machine Learning algorithms require numerical input, so numerical features can be directly used or further processed before modelling.

# %%
numerical_cols = df.select_dtypes(include="number").columns

print("Numerical Columns:")
print(list(numerical_cols))
# Out:
# Numerical Columns:
# ['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare']

# %% [markdown]
# # 3. Categorical Data
#
# ## Concept
#
# Categorical data contains values that represent groups or categories rather than continuous numerical measurements.
#
# ## Example
#
# In the Titanic dataset, `Sex`, `Ticket`, `Cabin`, and `Embarked` contain categorical information.
#
# ## Implementation
#
# We can identify categorical columns using `select_dtypes()`.
#
# ## Output
#
# The categorical columns are displayed.
#
# ## Interpretation
#
# These columns cannot always be directly given to a Machine Learning model and may need encoding.
#
# ## Insight
#
# The dataset contains several categorical features that need to be handled differently from numerical features.
#
# ## AI/ML Relevance
#
# Categorical features are commonly converted into numerical form using techniques such as one-hot encoding or label encoding.

# %%
import pandas as pd

df = pd.read_csv("Titanic-Dataset.csv")

print("Dataset loaded successfully.")
print(df.shape)
# Out:
# Dataset loaded successfully.
# (891, 12)

# %% [markdown]
# ## Identifying Data Types
#
# Categorical data represents values that belong to specific groups or categories.
#
# In the Titanic dataset, examples include `Sex`, `Ticket`, `Cabin`, and `Embarked`. These columns contain text or category-based information and should be handled differently from numerical features.
#
# Identifying categorical columns is important because Machine Learning models generally require categorical values to be converted into a suitable numerical format.
#
# ### Example
#
# For example, `Sex` contains categories such as `male` and `female`.
#
# ### Interpretation
#
# The output helps us identify which columns contain categorical information.
#
# ### Insight
#
# The Titanic dataset contains both numerical and categorical features, so different preprocessing techniques are required for different columns.
#
# ### AI/ML Relevance
#
# Correctly identifying categorical features helps us select appropriate techniques such as encoding before training a Machine Learning model.

# %%
categorical_cols = df.select_dtypes(include=["object", "string"]).columns

print("Categorical Columns:")
print(list(categorical_cols))
# Out:
# Categorical Columns:
# ['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked']

# %% [markdown]
# # 4. Boolean Data
#
# ## Concept
#
# Boolean data contains two logical values: `True` and `False`.
#
# ## Example
#
# A boolean column could represent whether a passenger survived, such as `True` for survived and `False` for not survived.
#
# The Titanic dataset does not contain a Boolean column by default, but `Survived` represents a binary outcome using 0 and 1.
#
# ## Implementation
#
# We can check whether the dataset contains Boolean columns.
#
# ## Output
#
# The Boolean columns, if available, are displayed.
#
# ## Interpretation
#
# If Boolean data exists, it can usually be converted into numerical form when required.
#
# ## Insight
#
# Understanding binary and Boolean features helps us prepare them correctly for Machine Learning.
#
# ## AI/ML Relevance
#
# Boolean variables can be represented as 0 and 1, making them suitable for many Machine Learning algorithms.

# %%
boolean_cols = df.select_dtypes(include="bool").columns

print("Boolean Columns:")
print(list(boolean_cols))
# Out:
# Boolean Columns:
# []

# %% [markdown]
# # 5. Date/Time Data
#
# ## Concept
#
# Date/time data represents information related to dates or time.
#
# ## Example
#
# A dataset may contain a column such as `Booking_Date` or `Travel_Date`.
#
# The Titanic dataset does not contain a date/time column, so there is no date conversion required here.
#
# ## Implementation
#
# We can check whether any datetime columns are already present.
#
# ## Output
#
# The datetime columns are displayed.
#
# ## Interpretation
#
# If date columns are stored as strings, they should be converted into proper datetime format.
#
# ## Insight
#
# Correct date/time types allow us to extract useful information such as year, month, day, or time.
#
# ## AI/ML Relevance
#
# Date/time features can provide useful patterns for Machine Learning after suitable transformation.

# %%
datetime_cols = df.select_dtypes(include="datetime").columns

print("Date/Time Columns:")
print(list(datetime_cols))
# Out:
# Date/Time Columns:
# []

# %% [markdown]
# # 6. String Data
#
# ## Concept
#
# String data contains text values.
#
# ## Example
#
# In the Titanic dataset, `Name` contains passenger names and is stored as text.
#
# ## Implementation
#
# We can identify string columns using the `object` data type.
#
# ## Output
#
# The string/categorical columns are displayed.
#
# ## Interpretation
#
# Some string columns may contain useful information, while others may need to be transformed or excluded depending on the Machine Learning objective.
#
# ## Insight
#
# Not every text column should automatically be converted into numbers. We first need to understand what information it contains.
#
# ## AI/ML Relevance
#
# Proper handling of text and categorical columns prevents errors and helps create useful model features.

# %%
string_cols = df.select_dtypes(include=["object", "string"]).columns

print("String Columns:")
print(list(string_cols))
# Out:
# String Columns:
# ['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked']

# %% [markdown]
# # 7. Converting Data Types
#
# ## Concept
#
# Sometimes a column is stored using an incorrect data type. Data type conversion changes it into the appropriate format.
#
# ## Example
#
# A numeric column stored as text should be converted into a numerical type before performing calculations.
#
# ## Implementation
#
# We can use Pandas functions such as `astype()`, `to_numeric()`, and `to_datetime()`.
#
# ## Output
#
# The data type before and after conversion can be compared.
#
# ## Interpretation
#
# The conversion confirms that the column is now stored using the required data type.
#
# ## Insight
#
# Correct conversion makes the data easier to analyze and prevents calculation errors.
#
# ## AI/ML Relevance
#
# Machine Learning preprocessing depends on correctly formatted features, so data type conversion is an important preprocessing step.

# %%
print("Original Age Data Type:")
print(df["Age"].dtype)

df["Age"] = pd.to_numeric(df["Age"], errors="coerce")

print("\nUpdated Age Data Type:")
print(df["Age"].dtype)
# Out:
# Original Age Data Type:
# float64
#
# Updated Age Data Type:
# float64

# %% [markdown]
# # 8. astype()
#
# ## Concept
#
# `astype()` is used to explicitly convert a Pandas column into a specified data type.
#
# ## Example
#
# We can convert the `Pclass` column from integer to string when we want to treat passenger class as a category.
#
# ## Implementation
#
# The column is converted using `astype()`.
#
# ## Output
#
# The updated data type is displayed.
#
# ## Interpretation
#
# The column is now stored as a string instead of an integer.
#
# ## Insight
#
# The same values can represent different meanings depending on how the feature is used.
#
# ## AI/ML Relevance
#
# Choosing the correct representation helps us apply appropriate preprocessing techniques to Machine Learning features.

# %%
df["Pclass_category"] = df["Pclass"].astype(str)

print(df["Pclass_category"].dtype)
print(df["Pclass_category"].head())
# Out:
# str
# 0    3
# 1    1
# 2    3
# 3    1
# 4    3
# Name: Pclass_category, dtype: str

# %% [markdown]
# # 9. to_numeric()
#
# ## Concept
#
# `pd.to_numeric()` converts values into numerical form.
#
# ## Example
#
# If a column contains numbers stored as strings, it can be converted into numeric values.
#
# ## Implementation
#
# We use `errors="coerce"` so that invalid values are converted to missing values instead of causing an error.
#
# ## Output
#
# The converted column and its data type are displayed.
#
# ## Interpretation
#
# Valid numerical values remain numeric, while invalid values become `NaN`.
#
# ## Insight
#
# This method is useful when datasets contain mixed or inconsistent numerical values.
#
# ## AI/ML Relevance
#
# Numerical features must be properly converted before statistical analysis and Machine Learning.

# %%
age_numeric = pd.to_numeric(df["Age"], errors="coerce")

print(age_numeric.head())
print("\nData Type:", age_numeric.dtype)
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# Name: Age, dtype: float64
#
# Data Type: float64

# %% [markdown]
# # 10. to_datetime()
#
# ## Concept
#
# `pd.to_datetime()` converts values into a proper date/time format.
#
# ## Example
#
# For example, a value such as `"2026-08-25"` stored as text can be converted into a datetime value.
#
# The Titanic dataset does not contain a date column, so we demonstrate the method using a small example.
#
# ## Implementation
#
# We convert string dates into datetime values.
#
# ## Output
#
# The converted values and their data type are displayed.
#
# ## Interpretation
#
# The values are now recognized as dates instead of normal strings.
#
# ## Insight
#
# Proper datetime conversion makes it possible to extract useful information such as year, month, and day.
#
# ## AI/ML Relevance
#
# Date-based features can be transformed into meaningful numerical features for Machine Learning.

# %%
dates = pd.Series(["2026-08-25", "2026-08-26"])

dates = pd.to_datetime(dates)

print(dates)
print("\nData Type:", dates.dtype)
# Out:
# 0   2026-08-25
# 1   2026-08-26
# dtype: datetime64[us]
#
# Data Type: datetime64[us]

# %% [markdown]
# # 11. Handling Invalid Conversions
#
# ## Concept
#
# Real-world datasets may contain invalid values that cannot be converted into the required data type.
#
# ## Example
#
# A numerical column may contain values such as `"unknown"` or `"not available"`.
#
# ## Implementation
#
# Using `errors="coerce"` converts invalid values into `NaN`.
#
# ## Output
#
# Invalid values are shown as missing values.
#
# ## Interpretation
#
# This prevents the program from stopping because of conversion errors.
#
# ## Insight
#
# Invalid values should not simply be ignored. They should be identified and handled during later preprocessing.
#
# ## AI/ML Relevance
#
# Handling invalid values prevents data errors and helps maintain reliable input for Machine Learning models.

# %%
example_values = pd.Series(["100", "250", "unknown", "500"])

converted = pd.to_numeric(example_values, errors="coerce")

print(converted)
# Out:
# 0    100.0
# 1    250.0
# 2      NaN
# 3    500.0
# dtype: float64

# %% [markdown]
# # 12. Detecting Incorrect Data Types
#
# ## Concept
#
# An incorrect data type occurs when a column is stored differently from how the data should logically be used.
#
# ## Example
#
# If age values are stored as text instead of numbers, numerical calculations cannot be performed correctly.
#
# ## Implementation
#
# We check the data types and identify columns that may require conversion.
#
# ## Output
#
# The data types of the Titanic dataset are displayed.
#
# ## Interpretation
#
# The result helps us decide which columns require further preprocessing.
#
# ## Insight
#
# Data type checking should be performed before applying other preprocessing techniques.
#
# ## AI/ML Relevance
#
# Incorrect data types can cause errors during feature engineering, encoding, scaling, and model training.

# %%
print("Current Data Types:")
print(df.dtypes)

print("\nMissing Values:")
print(df.isnull().sum())
# Out:
# Current Data Types:
# PassengerId          int64
# Survived             int64
# Pclass               int64
# Name                   str
# Sex                    str
# Age                float64
# SibSp                int64
# Parch                int64
# Ticket                 str
# Fare               float64
# Cabin                  str
# Embarked               str
# Pclass_category        str
# dtype: object
#
# Missing Values:
# PassengerId          0
# Survived             0
# Pclass               0
# Name                 0
# Sex                  0
# Age                177
# SibSp                0
# Parch                0
# Ticket               0
# Fare                 0
# Cabin              687
# Embarked             2
# Pclass_category      0
# dtype: int64

# %% [markdown]
# # 13. Final Data Type Summary
#
# ## Concept
#
# After checking and converting the required columns, we review the dataset again to confirm that the data types are appropriate.
#
# ## Example
#
# For the Titanic dataset, numerical features such as `Age` and `Fare` should remain numerical, while features such as `Sex` and `Embarked` should be treated as categorical.
#
# ## Implementation
#
# We display the final data types.
#
# ## Output
#
# The final data type of each column is displayed.
#
# ## Interpretation
#
# The summary confirms the current structure of the dataset and highlights any columns that may need additional preprocessing.
#
# ## Insight
#
# Correct data types make the dataset more consistent and easier to prepare for the next preprocessing steps.
#
# ## AI/ML Relevance
#
# Proper data types are essential for encoding, scaling, feature engineering, and building reliable Machine Learning models.

# %%
print("Final Data Type Summary:")
print(df.dtypes)
# Out:
# Final Data Type Summary:
# PassengerId          int64
# Survived             int64
# Pclass               int64
# Name                   str
# Sex                    str
# Age                float64
# SibSp                int64
# Parch                int64
# Ticket                 str
# Fare               float64
# Cabin                  str
# Embarked               str
# Pclass_category        str
# dtype: object

# %% [markdown]
# # the actual Titanic columns we are working with include:

# %% [markdown]
# PassengerId
# Survived
# Pclass
# Name
# Sex
# Age
# SibSp
# Parch
# Ticket
# Fare
# Cabin
# Embarked
